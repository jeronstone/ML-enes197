# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: folium in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (0.13.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (3.6.0)
# Collecting mapclassify
#   Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Collecting contextily==1.5.0
#   Downloading contextily-1.5.0-py3-none-any.whl (17 kB)
# Collecting pyjanitor
#   Downloading pyjanitor-0.26.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 24.7 MB/s eta 0:00:00
# Collecting siuba==0.4.4
#   Downloading siuba-0.4.4-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 kB 35.3 MB/s eta 0:00:00
# Collecting plotnine==0.12.4
#   Downloading plotnine-0.12.4-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.9 MB/s eta 0:00:00
# Collecting xyzservices
#   Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 14.1 MB/s eta 0:00:00
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from contextily==1.5.0->-r ./requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from contextily==1.5.0->-r ./requirements.txt (line 4)) (9.2.0)
# Collecting rasterio
#   Downloading rasterio-1.3.9-cp39-cp39-manylinux2014_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from contextily==1.5.0->-r ./requirements.txt (line 4)) (2.28.1)
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: SQLAlchemy>=1.2.19 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from siuba==0.4.4->-r ./requirements.txt (line 6)) (1.4.42)
# Collecting PyYAML>=3.0.0
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 72.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.1.0,>=0.24.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from siuba==0.4.4->-r ./requirements.txt (line 6)) (1.2.5)
# Requirement already satisfied: numpy>=1.12.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from siuba==0.4.4->-r ./requirements.txt (line 6)) (1.23.4)
# Collecting statsmodels>=0.14.0
#   Downloading statsmodels-0.14.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 100.7 MB/s eta 0:00:00
# Collecting pandas<2.1.0,>=0.24.0
#   Downloading pandas-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 66.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from plotnine==0.12.4->-r ./requirements.txt (line 7)) (1.9.3)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 34.6 MB/s eta 0:00:00
# Collecting mizani<0.10.0,>0.9.0
#   Downloading mizani-0.9.3-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: branca>=0.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from folium->-r ./requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from folium->-r ./requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (21.3)
# Collecting networkx>=2.7
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 97.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mapclassify->-r ./requirements.txt (line 3)) (1.1.2)
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Collecting pandas-flavor
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Collecting multipledispatch
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2>=2.9->folium->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<2.1.0,>=0.24.0->siuba==0.4.4->-r ./requirements.txt (line 6)) (2022.5)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<2.1.0,>=0.24.0->siuba==0.4.4->-r ./requirements.txt (line 6)) (2022.5)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine==0.12.4->-r ./requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify->-r ./requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from SQLAlchemy>=1.2.19->siuba==0.4.4->-r ./requirements.txt (line 6)) (1.1.3.post0)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: click>=3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mercantile->contextily==1.5.0->-r ./requirements.txt (line 4)) (8.1.3)
# Collecting xarray
#   Downloading xarray-2024.1.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 83.8 MB/s eta 0:00:00
# Requirement already satisfied: click-plugins in /shared-libs/python3.9/py/lib/python3.9/site-packages (from rasterio->contextily==1.5.0->-r ./requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: certifi in /shared-libs/python3.9/py/lib/python3.9/site-packages (from rasterio->contextily==1.5.0->-r ./requirements.txt (line 4)) (2022.9.24)
# Requirement already satisfied: attrs in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rasterio->contextily==1.5.0->-r ./requirements.txt (line 4)) (22.1.0)
# Requirement already satisfied: cligj>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from rasterio->contextily==1.5.0->-r ./requirements.txt (line 4)) (0.7.2)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from rasterio->contextily==1.5.0->-r ./requirements.txt (line 4)) (58.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->contextily==1.5.0->-r ./requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->contextily==1.5.0->-r ./requirements.txt (line 4)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->contextily==1.5.0->-r ./requirements.txt (line 4)) (3.4)
# Collecting packaging>=20.0
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: multipledispatch, xyzservices, snuggs, PyYAML, patsy, packaging, networkx, natsort, mercantile, geographiclib, affine, rasterio, pandas, geopy, xarray, statsmodels, siuba, mizani, mapclassify, contextily, plotnine, pandas-flavor, pyjanitor
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Not uninstalling packaging at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'packaging'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.3.5 requires packaging<22.0.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# Successfully installed PyYAML-6.0.1 affine-2.4.0 contextily-1.5.0 geographiclib-2.0 geopy-2.4.1 mapclassify-2.6.1 mercantile-1.2.1 mizani-0.9.3 multipledispatch-1.0.0 natsort-8.4.0 networkx-3.2.1 packaging-23.2 pandas-2.0.3 pandas-flavor-0.6.0 patsy-0.5.6 plotnine-0.12.4 pyjanitor-0.26.0 rasterio-1.3.9 siuba-0.4.4 snuggs-1.4.7 statsmodels-0.14.1 xarray-2024.1.0 xyzservices-2023.10.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d3020f8b-87b2-463d-8455-64b930c787e3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
